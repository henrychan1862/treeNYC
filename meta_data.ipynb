# %% [markdown]
# # Libraries

# %%
import pandas as pd   # for parsing query into dataframe
import time

# %% [markdown]
# # Initialise Client API

# %% [markdown]
# Indicate the project used for making query

# %%
from google.cloud import bigquery
client = bigquery.Client(project="treenyc-384104") # mark the created project id

# %% [markdown]
# # Explore Public Datasets

# %%
# this will get the names and descriptions of public datasets 
with open("meta/public_ds.txt", 'w') as f:
    for ds in client.list_datasets(project='bigquery-public-data'):
        f.write(ds.dataset_id + ": " + str(client.get_dataset(ds.reference).description)[:100] + '\n')
    f.close()

# %%
def get_tables(dataset, client = client):
    """get table names and schema from given public dataset name"""
    for table in client.list_tables(f"bigquery-public-data.{dataset}"):
        table = client.get_table(table)
        print(table.full_table_id)
        print([item.name for item in table.schema])

    return

# %%
get_tables("geo_us_roads")
# Out:
# bigquery-public-data:geo_us_roads.all_roads_01
# ['road_geom', 'road_id', 'full_name', 'route_type', 'mtfcc_feature_class_code']
# bigquery-public-data:geo_us_roads.all_roads_02
# ['road_geom', 'road_id', 'full_name', 'route_type', 'mtfcc_feature_class_code']
# bigquery-public-data:geo_us_roads.all_roads_04
# ['road_geom', 'road_id', 'full_name', 'route_type', 'mtfcc_feature_class_code']
# bigquery-public-data:geo_us_roads.all_roads_05
# ['road_geom', 'road_id', 'full_name', 'route_type', 'mtfcc_feature_class_code']
# bigquery-public-data:geo_us_roads.all_roads_06
# ['road_geom', 'road_id', 'full_name', 'route_type', 'mtfcc_feature_class_code']
# bigquery-public-data:geo_us_roads.all_roads_08
# ['road_geom', 'road_id', 'full_name', 'route_type', 'mtfcc_feature_class_code']
# bigquery-public-data:geo_us_roads.all_roads_09
# ['road_geom', 'road_id', 'full_name', 'route_type', 'mtfcc_feature_class_code']
# bigquery-public-data:geo_us_roads.all_roads_10
# ['road_geom', 'road_id', 'full_name', 'route_type', 'mtfcc_feature_class_code']
# bigquery-public-data:geo_us_roads.all_roads_11
# ['road_geom', 'road_id', 'full_name', 'route_type', 'mtfcc_feature_class_code']
# bigquery-public-data:geo_us_roads.all_roads_12
# ['road_geom', 'road_id', 'full_name', 'route_type', 'mtfcc_feature_class_code']
# bigquery-public-data:geo_us_roads.all_roads_13
# ['road_geom', 'road_id', 'full_name', 'route_type', 'mtfcc_feature_class_code']
# bigquery-public-data:geo_us_roads.all_roads_15
# ['road_geom', 'road_id', 'full_name', 'route_type', 'mtfcc_feature_class_code']
# bigquery-public-data:geo_us_roads.all_roads_16
# ['road_geom', 'road_id', 'full_name', 'route_type', 'mtfcc_feature_class_code']
# bigquery-public-data:geo_us_roads.all_roads_17
# ['road_geom', 'road_id', 'full_name', 'route_type', 'mtfcc_feature_class_code']
# bigquery-public-data:geo_us_roads.all_roads_18
# ['road_geom', 'road_id', 'full_name', 'route_type', 'mtfcc_feature_class_code']
# bigquery-public-data:geo_us_roads.all_roads_19
# ['road_geom', 'road_id', 'full_name', 'route_type', 'mtfcc_feature_class_code']
# bigquery-public-data:geo_us_roads.all_roads_20
# ['road_geom', 'road_id', 'full_name', 'route_type', 'mtfcc_feature_class_code']
# bigquery-public-data:geo_us_roads.all_roads_21
# ['road_geom', 'road_id', 'full_name', 'route_type', 'mtfcc_feature_class_code']
# bigquery-public-data:geo_us_roads.all_roads_22
# ['road_geom', 'road_id', 'full_name', 'route_type', 'mtfcc_feature_class_code']
# bigquery-public-data:geo_us_roads.all_roads_23
# ['road_geom', 'road_id', 'full_name', 'route_type', 'mtfcc_feature_class_code']
# bigquery-public-data:geo_us_roads.all_roads_24
# ['road_geom', 'road_id', 'full_name', 'route_type', 'mtfcc_feature_class_code']
# bigquery-public-data:geo_us_roads.all_roads_25
# ['road_geom', 'road_id', 'full_name', 'route_type', 'mtfcc_feature_class_code']
# bigquery-public-data:geo_us_roads.all_roads_26
# ['road_geom', 'road_id', 'full_name', 'route_type', 'mtfcc_feature_class_code']
# bigquery-public-data:geo_us_roads.all_roads_27
# ['road_geom', 'road_id', 'full_name', 'route_type', 'mtfcc_feature_class_code']
# bigquery-public-data:geo_us_roads.all_roads_28
# ['road_geom', 'road_id', 'full_name', 'route_type', 'mtfcc_feature_class_code']
# bigquery-public-data:geo_us_roads.all_roads_29
# ['road_geom', 'road_id', 'full_name', 'route_type', 'mtfcc_feature_class_code']
# bigquery-public-data:geo_us_roads.all_roads_30
# ['road_geom', 'road_id', 'full_name', 'route_type', 'mtfcc_feature_class_code']
# bigquery-public-data:geo_us_roads.all_roads_31
# ['road_geom', 'road_id', 'full_name', 'route_type', 'mtfcc_feature_class_code']
# bigquery-public-data:geo_us_roads.all_roads_32
# ['road_geom', 'road_id', 'full_name', 'route_type', 'mtfcc_feature_class_code']
# bigquery-public-data:geo_us_roads.all_roads_33
# ['road_geom', 'road_id', 'full_name', 'route_type', 'mtfcc_feature_class_code']
# bigquery-public-data:geo_us_roads.all_roads_34
# ['road_geom', 'road_id', 'full_name', 'route_type', 'mtfcc_feature_class_code']
# bigquery-public-data:geo_us_roads.all_roads_35
# ['road_geom', 'road_id', 'full_name', 'route_type', 'mtfcc_feature_class_code']
# bigquery-public-data:geo_us_roads.all_roads_36
# ['road_geom', 'road_id', 'full_name', 'route_type', 'mtfcc_feature_class_code']
# bigquery-public-data:geo_us_roads.all_roads_37
# ['road_geom', 'road_id', 'full_name', 'route_type', 'mtfcc_feature_class_code']
# bigquery-public-data:geo_us_roads.all_roads_38
# ['road_geom', 'road_id', 'full_name', 'route_type', 'mtfcc_feature_class_code']
# bigquery-public-data:geo_us_roads.all_roads_39
# ['road_geom', 'road_id', 'full_name', 'route_type', 'mtfcc_feature_class_code']
# bigquery-public-data:geo_us_roads.all_roads_40
# ['road_geom', 'road_id', 'full_name', 'route_type', 'mtfcc_feature_class_code']
# bigquery-public-data:geo_us_roads.all_roads_41
# ['road_geom', 'road_id', 'full_name', 'route_type', 'mtfcc_feature_class_code']
# bigquery-public-data:geo_us_roads.all_roads_42
# ['road_geom', 'road_id', 'full_name', 'route_type', 'mtfcc_feature_class_code']
# bigquery-public-data:geo_us_roads.all_roads_44
# ['road_geom', 'road_id', 'full_name', 'route_type', 'mtfcc_feature_class_code']
# bigquery-public-data:geo_us_roads.all_roads_45
# ['road_geom', 'road_id', 'full_name', 'route_type', 'mtfcc_feature_class_code']
# bigquery-public-data:geo_us_roads.all_roads_46
# ['road_geom', 'road_id', 'full_name', 'route_type', 'mtfcc_feature_class_code']
# bigquery-public-data:geo_us_roads.all_roads_47
# ['road_geom', 'road_id', 'full_name', 'route_type', 'mtfcc_feature_class_code']
# bigquery-public-data:geo_us_roads.all_roads_48
# ['road_geom', 'road_id', 'full_name', 'route_type', 'mtfcc_feature_class_code']
# bigquery-public-data:geo_us_roads.all_roads_49
# ['road_geom', 'road_id', 'full_name', 'route_type', 'mtfcc_feature_class_code']
# bigquery-public-data:geo_us_roads.all_roads_50
# ['road_geom', 'road_id', 'full_name', 'route_type', 'mtfcc_feature_class_code']
# bigquery-public-data:geo_us_roads.all_roads_51
# ['road_geom', 'road_id', 'full_name', 'route_type', 'mtfcc_feature_class_code']
# bigquery-public-data:geo_us_roads.all_roads_53
# ['road_geom', 'road_id', 'full_name', 'route_type', 'mtfcc_feature_class_code']
# ---------------------------------------------------------------------------
#
# KeyboardInterrupt                         Traceback (most recent call last)
#
# Cell In[4], line 1
#
# ----> 1 get_tables("geo_us_roads")
#
#
#
# Cell In[3], line 4, in get_tables(dataset, client)
#
#       2 """get table names and schema from given public dataset name"""
#
#       3 for table in client.list_tables(f"bigquery-public-data.{dataset}"):
#
# ----> 4     table = client.get_table(table)
#
#       5     print(table.full_table_id)
#
#       6     print([item.name for item in table.schema])
#
#
#
# File c:\Users\chanh\treeNYC\.venv\Lib\site-packages\google\cloud\bigquery\client.py:1065, in Client.get_table(self, table, retry, timeout)
#
#    1063 path = table_ref.path
#
#    1064 span_attributes = {"path": path}
#
# -> 1065 api_response = self._call_api(
#
#    1066     retry,
#
#    1067     span_name="BigQuery.getTable",
#
#    1068     span_attributes=span_attributes,
#
#    1069     method="GET",
#
#    1070     path=path,
#
#    1071     timeout=timeout,
#
#    1072 )
#
#    1073 return Table.from_api_repr(api_response)
#
#
#
# File c:\Users\chanh\treeNYC\.venv\Lib\site-packages\google\cloud\bigquery\client.py:813, in Client._call_api(self, retry, span_name, span_attributes, job_ref, headers, **kwargs)
#
#     809 if span_name is not None:
#
#     810     with create_span(
#
#     811         name=span_name, attributes=span_attributes, client=self, job_ref=job_ref
#
#     812     ):
#
# --> 813         return call()
#
#     815 return call()
#
#
#
# File c:\Users\chanh\treeNYC\.venv\Lib\site-packages\google\api_core\retry.py:349, in Retry.__call__.<locals>.retry_wrapped_func(*args, **kwargs)
#
#     345 target = functools.partial(func, *args, **kwargs)
#
#     346 sleep_generator = exponential_sleep_generator(
#
#     347     self._initial, self._maximum, multiplier=self._multiplier
#
#     348 )
#
# --> 349 return retry_target(
#
#     350     target,
#
#     351     self._predicate,
#
#     352     sleep_generator,
#
#     353     self._timeout,
#
#     354     on_error=on_error,
#
#     355 )
#
#
#
# File c:\Users\chanh\treeNYC\.venv\Lib\site-packages\google\api_core\retry.py:191, in retry_target(target, predicate, sleep_generator, timeout, on_error, **kwargs)
#
#     189 for sleep in sleep_generator:
#
#     190     try:
#
# --> 191         return target()
#
#     193     # pylint: disable=broad-except
#
#     194     # This function explicitly must deal with broad exceptions.
#
#     195     except Exception as exc:
#
#
#
# File c:\Users\chanh\treeNYC\.venv\Lib\site-packages\google\cloud\_http\__init__.py:482, in JSONConnection.api_request(self, method, path, query_params, data, content_type, headers, api_base_url, api_version, expect_json, _target_object, timeout, extra_api_info)
#
#     479     data = json.dumps(data)
#
#     480     content_type = "application/json"
#
# --> 482 response = self._make_request(
#
#     483     method=method,
#
#     484     url=url,
#
#     485     data=data,
#
#     486     content_type=content_type,
#
#     487     headers=headers,
#
#     488     target_object=_target_object,
#
#     489     timeout=timeout,
#
#     490     extra_api_info=extra_api_info,
#
#     491 )
#
#     493 if not 200 <= response.status_code < 300:
#
#     494     raise exceptions.from_http_response(response)
#
#
#
# File c:\Users\chanh\treeNYC\.venv\Lib\site-packages\google\cloud\_http\__init__.py:341, in JSONConnection._make_request(self, method, url, data, content_type, headers, target_object, timeout, extra_api_info)
#
#     338     headers[CLIENT_INFO_HEADER] = self.user_agent
#
#     339 headers["User-Agent"] = self.user_agent
#
# --> 341 return self._do_request(
#
#     342     method, url, headers, data, target_object, timeout=timeout
#
#     343 )
#
#
#
# File c:\Users\chanh\treeNYC\.venv\Lib\site-packages\google\cloud\_http\__init__.py:379, in JSONConnection._do_request(self, method, url, headers, data, target_object, timeout)
#
#     345 def _do_request(
#
#     346     self, method, url, headers, data, target_object, timeout=_DEFAULT_TIMEOUT
#
#     347 ):  # pylint: disable=unused-argument
#
#     348     """Low-level helper:  perform the actual API request over HTTP.
#
#     349
#
#     350     Allows batch context managers to override and defer a request.
#
#    (...)
#
#     377     :returns: The HTTP response.
#
#     378     """
#
# --> 379     return self.http.request(
#
#     380         url=url, method=method, headers=headers, data=data, timeout=timeout
#
#     381     )
#
#
#
# File c:\Users\chanh\treeNYC\.venv\Lib\site-packages\google\auth\transport\requests.py:549, in AuthorizedSession.request(self, method, url, data, headers, max_allowed_time, timeout, **kwargs)
#
#     546 remaining_time = guard.remaining_timeout
#
#     548 with TimeoutGuard(remaining_time) as guard:
#
# --> 549     response = super(AuthorizedSession, self).request(
#
#     550         method,
#
#     551         url,
#
#     552         data=data,
#
#     553         headers=request_headers,
#
#     554         timeout=timeout,
#
#     555         **kwargs
#
#     556     )
#
#     557 remaining_time = guard.remaining_timeout
#
#     559 # If the response indicated that the credentials needed to be
#
#     560 # refreshed, then refresh the credentials and re-attempt the
#
#     561 # request.
#
#     562 # A stored token may expire between the time it is retrieved and
#
#     563 # the time the request is made, so we may need to try twice.
#
#
#
# File c:\Users\chanh\treeNYC\.venv\Lib\site-packages\requests\sessions.py:587, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#
#     582 send_kwargs = {
#
#     583     "timeout": timeout,
#
#     584     "allow_redirects": allow_redirects,
#
#     585 }
#
#     586 send_kwargs.update(settings)
#
# --> 587 resp = self.send(prep, **send_kwargs)
#
#     589 return resp
#
#
#
# File c:\Users\chanh\treeNYC\.venv\Lib\site-packages\requests\sessions.py:701, in Session.send(self, request, **kwargs)
#
#     698 start = preferred_clock()
#
#     700 # Send the request
#
# --> 701 r = adapter.send(request, **kwargs)
#
#     703 # Total elapsed time of the request (approximately)
#
#     704 elapsed = preferred_clock() - start
#
#
#
# File c:\Users\chanh\treeNYC\.venv\Lib\site-packages\requests\adapters.py:489, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#
#     487 try:
#
#     488     if not chunked:
#
# --> 489         resp = conn.urlopen(
#
#     490             method=request.method,
#
#     491             url=url,
#
#     492             body=request.body,
#
#     493             headers=request.headers,
#
#     494             redirect=False,
#
#     495             assert_same_host=False,
#
#     496             preload_content=False,
#
#     497             decode_content=False,
#
#     498             retries=self.max_retries,
#
#     499             timeout=timeout,
#
#     500         )
#
#     502     # Send the request.
#
#     503     else:
#
#     504         if hasattr(conn, "proxy_pool"):
#
#
#
# File c:\Users\chanh\treeNYC\.venv\Lib\site-packages\urllib3\connectionpool.py:703, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#
#     700     self._prepare_proxy(conn)
#
#     702 # Make the request on the httplib connection object.
#
# --> 703 httplib_response = self._make_request(
#
#     704     conn,
#
#     705     method,
#
#     706     url,
#
#     707     timeout=timeout_obj,
#
#     708     body=body,
#
#     709     headers=headers,
#
#     710     chunked=chunked,
#
#     711 )
#
#     713 # If we're going to release the connection in ``finally:``, then
#
#     714 # the response doesn't need to know about the connection. Otherwise
#
#     715 # it will also try to release it and we'll have a double-release
#
#     716 # mess.
#
#     717 response_conn = conn if not release_conn else None
#
#
#
# File c:\Users\chanh\treeNYC\.venv\Lib\site-packages\urllib3\connectionpool.py:449, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#
#     444             httplib_response = conn.getresponse()
#
#     445         except BaseException as e:
#
#     446             # Remove the TypeError from the exception chain in
#
#     447             # Python 3 (including for exceptions like SystemExit).
#
#     448             # Otherwise it looks like a bug in the code.
#
# --> 449             six.raise_from(e, None)
#
#     450 except (SocketTimeout, BaseSSLError, SocketError) as e:
#
#     451     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
#
#
# File <string>:3, in raise_from(value, from_value)
#
#
#
# File c:\Users\chanh\treeNYC\.venv\Lib\site-packages\urllib3\connectionpool.py:444, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#
#     441 except TypeError:
#
#     442     # Python 3
#
#     443     try:
#
# --> 444         httplib_response = conn.getresponse()
#
#     445     except BaseException as e:
#
#     446         # Remove the TypeError from the exception chain in
#
#     447         # Python 3 (including for exceptions like SystemExit).
#
#     448         # Otherwise it looks like a bug in the code.
#
#     449         six.raise_from(e, None)
#
#
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\http\client.py:1375, in HTTPConnection.getresponse(self)
#
#    1373 try:
#
#    1374     try:
#
# -> 1375         response.begin()
#
#    1376     except ConnectionError:
#
#    1377         self.close()
#
#
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\http\client.py:318, in HTTPResponse.begin(self)
#
#     316 # read until we get a non-100 response
#
#     317 while True:
#
# --> 318     version, status, reason = self._read_status()
#
#     319     if status != CONTINUE:
#
#     320         break
#
#
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\http\client.py:279, in HTTPResponse._read_status(self)
#
#     278 def _read_status(self):
#
# --> 279     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#
#     280     if len(line) > _MAXLINE:
#
#     281         raise LineTooLong("status line")
#
#
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\socket.py:706, in SocketIO.readinto(self, b)
#
#     704 while True:
#
#     705     try:
#
# --> 706         return self._sock.recv_into(b)
#
#     707     except timeout:
#
#     708         self._timeout_occurred = True
#
#
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\ssl.py:1278, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#
#    1274     if flags != 0:
#
#    1275         raise ValueError(
#
#    1276           "non-zero flags not allowed in calls to recv_into() on %s" %
#
#    1277           self.__class__)
#
# -> 1278     return self.read(nbytes, buffer)
#
#    1279 else:
#
#    1280     return super().recv_into(buffer, nbytes, flags)
#
#
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\ssl.py:1134, in SSLSocket.read(self, len, buffer)
#
#    1132 try:
#
#    1133     if buffer is not None:
#
# -> 1134         return self._sslobj.read(len, buffer)
#
#    1135     else:
#
#    1136         return self._sslobj.read(len)
#
#
#
# KeyboardInterrupt:

# %% [markdown]
# # Retrieve Schema

# %% [markdown]
# Retrieve schemas for each tables to check compatability.

# %%
# get tables name inside dataset
table_names = [table.table_id for table in client.list_tables("bigquery-public-data.new_york_trees")]
print(table_names)
# Out:
# ['tree_census_1995', 'tree_census_2005', 'tree_census_2015', 'tree_species']

# %%
descrption_dfs = {}
for table in client.list_tables("bigquery-public-data.new_york_trees"):
    table_schema = client.get_table(table).schema
    table_metadata = pd.DataFrame(
        {
            "Name" : [item.name for item in table_schema],
            "Dtype" : [item.field_type for item in table_schema],
            "Example" : client.list_rows(table=table, max_results=1).to_dataframe().values.flatten(),
            "Description":[item.description for item in table_schema],
        }
    )
    with open(f"meta/{table.table_id}_meta.txt", 'w') as f:
        f.write(table_metadata.to_markdown())
        f.close()
    descrption_dfs[table.table_id] = table_metadata

# %% [markdown]
# Count number of rows in tables

# %%
for table in client.list_tables("bigquery-public-data.new_york_trees"):
    table = client.get_table(table)
    print(f"{table.table_id}: {table.num_rows}")
# Out:
# tree_census_1995: 516989
# tree_census_2005: 592372
# tree_census_2015: 683788
# tree_species: 57

# %% [markdown]
# # Query

# %%
def query_to_df(query_script, client=client):
    """pass a SQL query, return as pandas dataframe"""
    start = time.time()
    query = client.query(query_script) # create query
    df = query.to_dataframe()   # convert into pandas dataframe
    print(f"Query Time...{time.time()-start:.3}")  # retrieve query time
    print(df.info())

    return df

# %% [markdown]
# Write the query using SQL

# %%
QUERY = (   # query in SQL style
    """
    SELECT *
    FROM `bigquery-public-data.new_york_trees.tree_census_2005`
    LIMIT 100
    """
)

# %% [markdown]
# Run the main query and get as a pandas dataframe

# %%
df = query_to_df(QUERY)
# Out:
# Query Time...1.92
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 54 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   objectid      100 non-null    Int64
#  1   cen_year      100 non-null    Int64
#  2   tree_dbh      100 non-null    Int64
#  3   tree_loc      100 non-null    object
#  4   pit_type      100 non-null    object
#  5   soil_lvl      100 non-null    object
#  6   status        100 non-null    object
#  7   spc_latin     100 non-null    object
#  8   spc_common    100 non-null    object
#  9   vert_other    100 non-null    boolean
#  10  vert_pgrd     100 non-null    boolean
#  11  vert_tgrd     100 non-null    boolean
#  12  vert_wall     100 non-null    boolean
#  13  horz_blck     100 non-null    boolean
#  14  horz_grate    100 non-null    boolean
#  15  horz_plant    100 non-null    boolean
#  16  horz_other    100 non-null    boolean
#  17  sidw_crack    100 non-null    boolean
#  18  sidw_raise    100 non-null    boolean
#  19  wire_htap     100 non-null    boolean
#  20  wire_prime    100 non-null    boolean
#  21  wire_2nd      100 non-null    boolean
#  22  wire_other    100 non-null    boolean
#  23  inf_canopy    100 non-null    boolean
#  24  inf_guard     100 non-null    boolean
#  25  inf_wires     100 non-null    boolean
#  26  inf_paving    100 non-null    boolean
#  27  inf_outlet    100 non-null    boolean
#  28  inf_shoes     100 non-null    boolean
#  29  inf_lights    100 non-null    boolean
#  30  inf_other     100 non-null    boolean
#  31  trunk_dmg     100 non-null    object
#  32  zipcode       100 non-null    object
#  33  zip_city      0 non-null      object
#  34  cb_num        100 non-null    Int64
#  35  borocode      100 non-null    Int64
#  36  boroname      100 non-null    object
#  37  cncldist      100 non-null    Int64
#  38  st_assem      100 non-null    Int64
#  39  st_senate     100 non-null    Int64
#  40  nta           0 non-null      object
#  41  nta_name      0 non-null      object
#  42  boro_ct       0 non-null      Int64
#  43  x_sp          100 non-null    Int64
#  44  y_sp          100 non-null    Int64
#  45  objectid_1    100 non-null    Int64
#  46  location_1    100 non-null    object
#  47  state         100 non-null    object
#  48  latitude      100 non-null    float64
#  49  longitude     100 non-null    float64
#  50  census_tract  0 non-null      Int64
#  51  bin           0 non-null      Int64
#  52  bbl           0 non-null      Int64
#  53  address       100 non-null    object
# dtypes: Int64(15), boolean(22), float64(2), object(15)
# memory usage: 30.9+ KB
# None

# %% [markdown]
# # EDA

# %% [markdown]
# Explroe with variables of `tree_species`

# %%
tree_species = df.copy()
for column in tree_species.columns:
    print(column, ":", "\n",  tree_species[column].nunique(), tree_species[column].unique()[:5])
# Out:
# species_scientific_name :
#  57 ['Quercus phellos' 'Cotinus sp.' 'Prunus sargentii' 'Prunus padus'
#  "Prunus serrulata 'Kwanzan'"]
# species_common_name :
#  57 ['Willow Oak' 'Smoke Tree' 'Sargent Cherry' 'European Birdcherry'
#  'Japanese Flowering Cherry']
# form :
#  4 ['Rounded' 'Upright' 'Pyramidal' 'Vase–Like']
# growth_rate :
#  2 ['Slow' 'Medium']
# fall_color :
#  13 ['Yellow/Orange' 'Red/Bronze' 'Yellow/Bronze' 'Red/Orange' 'Red']
# environmental_tolerances :
#  30 ['Drought and Pollution Tolerant' 'none' 'Shade Tolerant'
#  'High pH Tolerant' 'Wet Site and Salt Tolerant']
# location_tolerances :
#  8 ['Median Tree' 'Small Tree Pit (<3 ft)'
#  'Median Tree, Small Tree Pit (<3 ft)'
#  'Small Tree Pit (<3 ft), Narrow Growing Space' 'none']
# notes_suggested_cultivars :
#  45 ['Plant Spring Only' "'Royal Purple' or 'Grace'"
#  "'Accolade' is Semi–double Flowering;"
#  'One of the First Trees to Leaf Out in the Spring' 'Double–flowering']
# tree_size :
#  4 ['Large (Mature Height > 50 ft)' 'Small (Mature Height < 25 ft)'
#  'Medium (Mature Height 35-50 ft)' 'Intermediate (Mature Height 25-35 ft)']
# comments :
#  2 [''
#  'Asian Long Horn Beetle Quarantine Species – Planting NOT RECOMMENDED in Brooklyn, Manhattan, Queens, and Staten Island']

# %%
tree_2005 = df.copy()
for column in tree_2005.columns:
    print(column, ":", tree_2005[column].nunique(), "==>", tree_2005[column].unique().tolist()[:5])
# Out:
# objectid : 100 ==> [1091298, 1091299, 1091300, 1091301, 1092323]
# cen_year : 1 ==> [0]
# tree_dbh : 21 ==> [7, 6, 5, 20, 10]
# tree_loc : 5 ==> ['Front', 'Side', 'Assigned', 'Median', 'Across']
# pit_type : 3 ==> ['Lawn', 'Continuous Pit', 'Sidewalk Pit']
# soil_lvl : 2 ==> ['Level', 'Above']
# status : 4 ==> ['Good', 'Excellent', 'Poor', 'Dead']
# spc_latin : 17 ==> ['UNKNOWN', 'GLEDITSIA TRIACANTHOS', 'PYRUS CALLERYANA', 'QUERCUS PALUSTRIS', 'LIQUIDAMBAR STYRACIFLUA']
# spc_common : 17 ==> ['UNKNOWN', 'HONEYLOCUST', 'PEAR, CALLERY', 'OAK, PIN', 'SWEETGUM']
# vert_other : 1 ==> [False]
# vert_pgrd : 1 ==> [False]
# vert_tgrd : 2 ==> [False, True]
# vert_wall : 1 ==> [False]
# horz_blck : 2 ==> [False, True]
# horz_grate : 1 ==> [False]
# horz_plant : 2 ==> [False, True]
# horz_other : 1 ==> [False]
# sidw_crack : 2 ==> [False, True]
# sidw_raise : 2 ==> [False, True]
# wire_htap : 1 ==> [False]
# wire_prime : 1 ==> [False]
# wire_2nd : 1 ==> [False]
# wire_other : 1 ==> [False]
# inf_canopy : 1 ==> [False]
# inf_guard : 1 ==> [False]
# inf_wires : 1 ==> [False]
# inf_paving : 1 ==> [False]
# inf_outlet : 1 ==> [False]
# inf_shoes : 1 ==> [False]
# inf_lights : 1 ==> [False]
# inf_other : 1 ==> [False]
# trunk_dmg : 4 ==> ['None', 'Trunk Wound', 'Torn Bark', 'Cavity']
# zipcode : 1 ==> ['0']
# zip_city : 0 ==> [None]
# cb_num : 1 ==> [0]
# borocode : 1 ==> [5]
# boroname : 1 ==> ['5']
# cncldist : 1 ==> [0]
# st_assem : 1 ==> [0]
# st_senate : 1 ==> [0]
# nta : 0 ==> [None]
# nta_name : 0 ==> [None]
# boro_ct : 0 ==> [<NA>]
# x_sp : 1 ==> [0]
# y_sp : 1 ==> [0]
# objectid_1 : 100 ==> [498925, 498926, 498927, 498928, 499950]
# location_1 : 1 ==> ['(0.0, 0.0)']
# state : 1 ==> ['New York']
# latitude : 1 ==> [0.0]
# longitude : 1 ==> [0.0]
# census_tract : 0 ==> [<NA>]
# bin : 0 ==> [<NA>]
# bbl : 0 ==> [<NA>]
# address : 21 ==> ['cememtary SHARROTT AVENUE', 'not listed DITSON STREET', 'not listed not listed', 'NOT LISTED DRUMGOOLE ROAD EAST', 'not listed SLOSSON AVENUE']
